# %%
import numpy as np
rng = np.random.default_rng()

# %%
x1 = rng.random(100) * 100
# sum of values in array
# %timeit sum(x1)
# %timeit np.sum(x1)

# min and max of array
print("min is ", np.min(x1))

print("max is ", np.max(x1))
# Out:
# 3.69 μs ± 62.1 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)
# 1.9 μs ± 641 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)
