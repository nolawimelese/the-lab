# %% [markdown]
# Writing down all of the shortcuts this book discusses

# %%
help(len)

len? #type: ignore
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %%
def foo_bar(foo: int, bar: int) -> int:
    '''Adds foo and bar'''
    n = bar + foo
    return n

# %%
help(foo_bar) #type: ignore
foo_bar??
# Out:
# Help on function foo_bar in module __main__:
#
# foo_bar(foo: int, bar: int) -> int
#     Adds foo and bar
# Signature: foo_bar(foo: int, bar: int) -> int
# Source:
# def foo_bar(foo: int, bar: int) -> int:
#     '''Adds foo and bar'''
#     n = bar + foo
#     return n
# File:      c:\users\nolaw\appdata\local\temp\ipykernel_2988\3917818173.py
# Type:      function

# %%
# %%timeit

for i in range(500000):
    pass
# Out:
# 4.68 ms ± 29.6 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
